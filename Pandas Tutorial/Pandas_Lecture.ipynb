# %% [markdown]
# <a href="https://colab.research.google.com/github/maturyusuf/Python_Lectures/blob/main/Pandas_Tutorial_Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
type(pd.read_csv("/content/Hitters.csv"))
df = pd.read_csv("/content/Hitters.csv")

# %%
df.head(7)
# Out:
#    AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns  \
# 0    293    66      1    30   29     14      1     293     66       1     30
# 1    315    81      7    24   38     39     14    3449    835      69    321
# 2    479   130     18    66   72     76      3    1624    457      63    224
# 3    496   141     20    65   78     37     11    5628   1575     225    828
# 4    321    87     10    39   42     30      2     396    101      12     48
# 5    594   169      4    74   51     35     11    4408   1133      19    501
# 6    185    37      1    23    8     21      2     214     42       1     30
#
#    CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary NewLeague
# 0    29      14      A        E      446       33      20     NaN         A
# 1   414     375      N        W      632       43      10   475.0         N
# 2   266     263      A        W      880       82      14   480.0         A
# ...

# %%
df.tail(7)
# Out:
#      AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  \
# 315    593   172     22    82  100     57      1     593    172      22
# 316    221    53      2    21   23     22      8    1063    283      15
# 317    497   127      7    65   48     37      5    2703    806      32
# 318    492   136      5    76   50     94     12    5511   1511      39
# 319    475   126      3    61   43     52      6    1700    433       7
# 320    573   144      9    85   60     78      8    3198    857      97
# 321    631   170      9    77   44     31     11    4908   1457      30
#
#      CRuns  CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary  \
# 315     82   100      57      A        W     1222      139      15   165.0
# 316    107   124     106      N        E      325       58       6     NaN
# 317    379   311     138      N        E      325        9       3   700.0
# 318    897   451     875      A        E      313      381      20   875.0
# ...

# %%
df.shape
# Out:
# (322, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   AtBat      322 non-null    int64
#  1   Hits       322 non-null    int64
#  2   HmRun      322 non-null    int64
#  3   Runs       322 non-null    int64
#  4   RBI        322 non-null    int64
#  5   Walks      322 non-null    int64
#  6   Years      322 non-null    int64
#  7   CAtBat     322 non-null    int64
#  8   CHits      322 non-null    int64
#  9   CHmRun     322 non-null    int64
#  10  CRuns      322 non-null    int64
#  11  CRBI       322 non-null    int64
#  12  CWalks     322 non-null    int64
#  13  League     322 non-null    object
#  14  Division   322 non-null    object
#  15  PutOuts    322 non-null    int64
#  16  Assists    322 non-null    int64
#  17  Errors     322 non-null    int64
#  18  Salary     263 non-null    float64
#  19  NewLeague  322 non-null    object
# ...

# %%
pd.set_option("display.max_columns", 20)

# %%
df
# Out:
#      Hits  AtBat  ...  Salary  NewLeague
# 0      66    293  ...     NaN          A
# 1      81    315  ...   475.0          N
# 2     130    479  ...   480.0          A
# 3     141    496  ...   500.0          N
# 4      87    321  ...    91.5          N
# ..    ...    ...  ...     ...        ...
# 317   127    497  ...   700.0          N
# 318   136    492  ...   875.0          A
# 319   126    475  ...   385.0          A
# 320   144    573  ...   960.0          A
# 321   170    631  ...  1000.0          A
#
# [322 rows x 20 columns]

# %%
pd.set_option("display.max_rows", 70,)
df
# Out:
#      AtBat  Hits  ...  Salary  NewLeague
# 0      293    66  ...     NaN          A
# 1      315    81  ...   475.0          N
# 2      479   130  ...   480.0          A
# 3      496   141  ...   500.0          N
# 4      321    87  ...    91.5          N
# ..     ...   ...  ...     ...        ...
# 317    497   127  ...   700.0          N
# 318    492   136  ...   875.0          A
# 319    475   126  ...   385.0          A
# 320    573   144  ...   960.0          A
# 321    631   170  ...  1000.0          A
#
# [322 rows x 20 columns]

# %%
df
# Out:
#      AtBat  Hits  ...  Salary  NewLeague
# 0      293    66  ...     NaN          A
# 1      315    81  ...   475.0          N
# 2      479   130  ...   480.0          A
# 3      496   141  ...   500.0          N
# 4      321    87  ...    91.5          N
# ..     ...   ...  ...     ...        ...
# 317    497   127  ...   700.0          N
# 318    492   136  ...   875.0          A
# 319    475   126  ...   385.0          A
# 320    573   144  ...   960.0          A
# 321    631   170  ...  1000.0          A
#
# [322 rows x 20 columns]

# %%
df.columns
# Out:
# Index(['AtBat', 'Hits', 'HmRun', 'Runs', 'RBI', 'Walks', 'Years', 'CAtBat',
#        'CHits', 'CHmRun', 'CRuns', 'CRBI', 'CWalks', 'League', 'Division',
#        'PutOuts', 'Assists', 'Errors', 'Salary', 'NewLeague'],
#       dtype='object')

# %%
type(df["NewLeague"])
# Out:
# pandas.core.series.Series

# %%
df_newLeague_Array = np.array(df["NewLeague"])

# %%
type(df_newLeague_Array)
# Out:
# numpy.ndarray

# %%
df.head(10)
# Out:
#    AtBat  Hits  ...  Salary  NewLeague
# 0    293    66  ...     NaN          A
# 1    315    81  ...   475.0          N
# 2    479   130  ...   480.0          A
# 3    496   141  ...   500.0          N
# 4    321    87  ...    91.5          N
# 5    594   169  ...   750.0          A
# 6    185    37  ...    70.0          A
# 7    298    73  ...   100.0          A
# 8    323    81  ...    75.0          N
# 9    401    92  ...  1100.0          A
#
# [10 rows x 20 columns]

# %%
df["NewLeague"].value_counts()
# Out:
# A    176
# N    146
# Name: NewLeague, dtype: int64

# %%
df.loc[4,["AtBat","Hits" ]]
# Out:
# AtBat    321
# Hits      87
# Name: 4, dtype: object

# %%
df.loc[4:,"AtBat":"Salary" ]
# Out:
#      AtBat  Hits  ...  Errors  Salary
# 4      321    87  ...       4    91.5
# 5      594   169  ...      25   750.0
# 6      185    37  ...       7    70.0
# 7      298    73  ...       9   100.0
# 8      323    81  ...      19    75.0
# ..     ...   ...  ...     ...     ...
# 317    497   127  ...       3   700.0
# 318    492   136  ...      20   875.0
# 319    475   126  ...       7   385.0
# 320    573   144  ...      12   960.0
# 321    631   170  ...       3  1000.0
#
# [318 rows x 19 columns]

# %%
df.iloc[5:7,0:4 ]
# Out:
#    AtBat  Hits  HmRun  Runs
# 5    594   169      4    74
# 6    185    37      1    23

# %%
df.set_index("Hits", inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df.sort_index(ascending = False)
# Out:
#      Hits  AtBat  ...  Salary  NewLeague
# 321   170    631  ...  1000.0          A
# 320   144    573  ...   960.0          A
# 319   126    475  ...   385.0          A
# 318   136    492  ...   875.0          A
# 317   127    497  ...   700.0          N
# ..    ...    ...  ...     ...        ...
# 4      87    321  ...    91.5          N
# 3     141    496  ...   500.0          N
# 2     130    479  ...   480.0          A
# 1      81    315  ...   475.0          N
# 0      66    293  ...     NaN          A
#
# [322 rows x 20 columns]

# %%
df["Salary"].sort_index(ascending = False)
# Out:
# 321    1000.0
# 320     960.0
# 319     385.0
# 318     875.0
# 317     700.0
#         ...
# 4        91.5
# 3       500.0
# 2       480.0
# 1       475.0
# 0         NaN
# Name: Salary, Length: 322, dtype: float64

# %%
#Filtering

filt = (df["NewLeague"] == "A")
filt
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 317    False
# 318     True
# 319     True
# 320     True
# 321     True
# Name: NewLeague, Length: 322, dtype: bool

# %%
df[filt][["Salary", "Hits"]]
# Out:
#      Salary  Hits
# 0       NaN    66
# 2     480.0   130
# 5     750.0   169
# 6      70.0    37
# 7     100.0    73
# ..      ...   ...
# 315   165.0   172
# 318   875.0   136
# 319   385.0   126
# 320   960.0   144
# 321  1000.0   170
#
# [176 rows x 2 columns]

# %%
df.loc[filt]
# Out:
#      Hits  AtBat  ...  Salary  NewLeague
# 0      66    293  ...     NaN          A
# 2     130    479  ...   480.0          A
# 5     169    594  ...   750.0          A
# 6      37    185  ...    70.0          A
# 7      73    298  ...   100.0          A
# ..    ...    ...  ...     ...        ...
# 315   172    593  ...   165.0          A
# 318   136    492  ...   875.0          A
# 319   126    475  ...   385.0          A
# 320   144    573  ...   960.0          A
# 321   170    631  ...  1000.0          A
#
# [176 rows x 20 columns]

# %%
df.loc[315:321,"Hits":"Salary"]
# Out:
#      Hits  AtBat  ...  Errors  Salary
# 315   172    593  ...      15   165.0
# 316    53    221  ...       6     NaN
# 317   127    497  ...       3   700.0
# 318   136    492  ...      20   875.0
# 319   126    475  ...       7   385.0
# 320   144    573  ...      12   960.0
# 321   170    631  ...       3  1000.0
#
# [7 rows x 19 columns]

# %%
df.drop(columns=["Hits"])
# Out:
#      AtBat  HmRun  ...  Salary  NewLeague
# 0      293      1  ...     NaN          A
# 1      315      7  ...   475.0          N
# 2      479     18  ...   480.0          A
# 3      496     20  ...   500.0          N
# 4      321     10  ...    91.5          N
# ..     ...    ...  ...     ...        ...
# 317    497      7  ...   700.0          N
# 318    492      5  ...   875.0          A
# 319    475      3  ...   385.0          A
# 320    573      9  ...   960.0          A
# 321    631      9  ...  1000.0          A
#
# [322 rows x 19 columns]

# %%
df.loc[filt,["Errors", "NewLeague", "Hits"]]
# Out:
#      Errors NewLeague  Hits
# 0        20         A    66
# 2        14         A   130
# 5        25         A   169
# 6         7         A    37
# 7         9         A    73
# ..      ...       ...   ...
# 315      15         A   172
# 318      20         A   136
# 319       7         A   126
# 320      12         A   144
# 321       3         A   170
#
# [176 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Hits       322 non-null    int64
#  1   AtBat      322 non-null    int64
#  2   HmRun      322 non-null    int64
#  3   Runs       322 non-null    int64
#  4   RBI        322 non-null    int64
#  5   Walks      322 non-null    int64
#  6   Years      322 non-null    int64
#  7   CAtBat     322 non-null    int64
#  8   CHits      322 non-null    int64
#  9   CHmRun     322 non-null    int64
#  10  CRuns      322 non-null    int64
#  11  CRBI       322 non-null    int64
#  12  CWalks     322 non-null    int64
#  13  League     322 non-null    object
#  14  Division   322 non-null    object
#  15  PutOuts    322 non-null    int64
#  16  Assists    322 non-null    int64
#  17  Errors     322 non-null    int64
#  18  Salary     263 non-null    float64
#  19  NewLeague  322 non-null    object
# ...

# %%
df2 = df.dropna()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 263 entries, 1 to 321
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Hits       263 non-null    int64
#  1   AtBat      263 non-null    int64
#  2   HmRun      263 non-null    int64
#  3   Runs       263 non-null    int64
#  4   RBI        263 non-null    int64
#  5   Walks      263 non-null    int64
#  6   Years      263 non-null    int64
#  7   CAtBat     263 non-null    int64
#  8   CHits      263 non-null    int64
#  9   CHmRun     263 non-null    int64
#  10  CRuns      263 non-null    int64
#  11  CRBI       263 non-null    int64
#  12  CWalks     263 non-null    int64
#  13  League     263 non-null    object
#  14  Division   263 non-null    object
#  15  PutOuts    263 non-null    int64
#  16  Assists    263 non-null    int64
#  17  Errors     263 non-null    int64
#  18  Salary     263 non-null    float64
#  19  NewLeague  263 non-null    object
# ...

# %%
df2 = df.dropna(subset = ["Hits", "NewLeague"])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Hits       322 non-null    int64
#  1   AtBat      322 non-null    int64
#  2   HmRun      322 non-null    int64
#  3   Runs       322 non-null    int64
#  4   RBI        322 non-null    int64
#  5   Walks      322 non-null    int64
#  6   Years      322 non-null    int64
#  7   CAtBat     322 non-null    int64
#  8   CHits      322 non-null    int64
#  9   CHmRun     322 non-null    int64
#  10  CRuns      322 non-null    int64
#  11  CRBI       322 non-null    int64
#  12  CWalks     322 non-null    int64
#  13  League     322 non-null    object
#  14  Division   322 non-null    object
#  15  PutOuts    322 non-null    int64
#  16  Assists    322 non-null    int64
#  17  Errors     322 non-null    int64
#  18  Salary     263 non-null    float64
#  19  NewLeague  322 non-null    object
# ...

# %%
df.head()
# Out:
#    Hits  AtBat  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns  \
# 0    66    293      1    30   29     14      1     293     66       1     30
# 1    81    315      7    24   38     39     14    3449    835      69    321
# 2   130    479     18    66   72     76      3    1624    457      63    224
# 3   141    496     20    65   78     37     11    5628   1575     225    828
# 4    87    321     10    39   42     30      2     396    101      12     48
#
#    CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary NewLeague
# 0    29      14      A        E      446       33      20     NaN         A
# 1   414     375      N        W      632       43      10   475.0         N
# 2   266     263      A        W      880       82      14   480.0         A
# 3   838     354      N        E      200       11       3   500.0         N
# 4    46      33      N        E      805       40       4    91.5         N

# %%
np.mean([1,2,3,4,5])
# Out:
# 3.0

# %%
salaryMean = np.mean(df["Salary"])

# %%
filt = ((df["Salary"] > salaryMean) & (df["NewLeague"] == "A"))

# %%
df.loc[filt, ["NewLeague", "Salary"]]

# %%
df2 = df.loc[ ~filt, ["NewLeague", "Salary"]]
df2
# Out:
#     NewLeague  Salary
# 0           A     NaN
# 1           N   475.0
# 2           A   480.0
# 3           N   500.0
# 4           N    91.5
# ..        ...     ...
# 314         N   120.0
# 315         A   165.0
# 316         N     NaN
# 317         N   700.0
# 319         A   385.0
#
# [271 rows x 2 columns]

# %%
df.head()
# Out:
#    Hits  AtBat  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns  \
# 0    66    293      1    30   29     14      1     293     66       1     30
# 1    81    315      7    24   38     39     14    3449    835      69    321
# 2   130    479     18    66   72     76      3    1624    457      63    224
# 3   141    496     20    65   78     37     11    5628   1575     225    828
# 4    87    321     10    39   42     30      2     396    101      12     48
#
#    CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary NewLeague
# 0    29      14      A        E      446       33      20     NaN         A
# 1   414     375      N        W      632       43      10   475.0         N
# 2   266     263      A        W      880       82      14   480.0         A
# 3   838     354      N        E      200       11       3   500.0         N
# 4    46      33      N        E      805       40       4    91.5         N

# %%
filt = ((df["Years"] > 10) | (df["Hits"] > 100)  )
df.loc[filt,["Years", "Hits"]]
# Out:
#      Years  Hits
# 1       14    81
# 2        3   130
# 3       11   141
# 5       11   169
# 9       13    92
# ..     ...   ...
# 317      5   127
# 318     12   136
# 319      6   126
# 320      8   144
# 321     11   170
#
# [198 rows x 2 columns]

# %%
LeagueList  = ["A", "B", "C"]



filt = (df["NewLeague"].isin(LeagueList))
df.loc[filt, "NewLeague"]
# Out:
# 0      A
# 2      A
# 5      A
# 6      A
# 7      A
#       ..
# 315    A
# 318    A
# 319    A
# 320    A
# 321    A
# Name: NewLeague, Length: 176, dtype: object

# %%
df2 = df.copy()

# %%
df2["League"] = [leaguevalue.lower() for leaguevalue  in df2["League"]]

df2["League"]
# Out:
# 0      a
# 1      n
# 2      a
# 3      n
# 4      n
#       ..
# 317    n
# 318    a
# 319    a
# 320    a
# 321    a
# Name: League, Length: 322, dtype: object

# %%
df.head()
# Out:
#    Hits  AtBat  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns  \
# 0    66    293      1    30   29     14      1     293     66       1     30
# 1    81    315      7    24   38     39     14    3449    835      69    321
# 2   130    479     18    66   72     76      3    1624    457      63    224
# 3   141    496     20    65   78     37     11    5628   1575     225    828
# 4    87    321     10    39   42     30      2     396    101      12     48
#
#    CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary NewLeague
# 0    29      14      A        E      446       33      20     NaN         A
# 1   414     375      N        W      632       43      10   475.0         N
# 2   266     263      A        W      880       82      14   480.0         A
# 3   838     354      N        E      200       11       3   500.0         N
# 4    46      33      N        E      805       40       4    91.5         N

# %%
df2.rename(columns={"Hits":"Player_Hits", "NewLeague":"New_League"}, inplace=True)

# %%
df2.head()
# Out:
#    Player_Hits  AtBat  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  \
# 0           66    293      1    30   29     14      1     293     66       1
# 1           81    315      7    24   38     39     14    3449    835      69
# 2          130    479     18    66   72     76      3    1624    457      63
# 3          141    496     20    65   78     37     11    5628   1575     225
# 4           87    321     10    39   42     30      2     396    101      12
#
#    CRuns  CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary  \
# 0     30    29      14      a        E      446       33      20     NaN
# 1    321   414     375      n        W      632       43      10   475.0
# 2    224   266     263      a        W      880       82      14   480.0
# 3    828   838     354      n        E      200       11       3   500.0
# 4     48    46      33      n        E      805       40       4    91.5
#
#   New_League
# 0          A
# 1          N
# 2          A
# ...

# %%
underscore_parse = df2.columns.str.replace("_", " ")
underscore_parse
# Out:
# Index(['Player Hits', 'AtBat', 'HmRun', 'Runs', 'RBI', 'Walks', 'Years',
#        'CAtBat', 'CHits', 'CHmRun', 'CRuns', 'CRBI', 'CWalks', 'League',
#        'Division', 'PutOuts', 'Assists', 'Errors', 'Salary', 'New League'],
#       dtype='object')
